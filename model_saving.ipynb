# %%
import joblib

joblib.dump(iso_model, "models/isolation_forest.pkl")
joblib.dump(xgb_model, "models/xgboost_model.pkl")

print("Models saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import joblib
# ----> 3 joblib.dump(iso_model, "models/isolation_forest.pkl")
#       4 joblib.dump(xgb_model, "models/xgboost_model.pkl")
#       6 print("Models saved successfully!")
#
# NameError: name 'iso_model' is not defined

# %%
lstm_autoencoder.save("models/lstm_autoencoder.keras")

print("LSTM model saved successfully!")
